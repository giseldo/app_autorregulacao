# %%
import pandas as pd

df = pd.read_csv("datasets/mslq.csv")

# %%
df
# Out:
#          tipo                      constructo id_questao  \
# 0   motivacao  Orientação a Metas Intrínsecas         q1
# 1   motivacao  Orientação a Metas Intrínsecas         q2
# 2   motivacao  Orientação a Metas Extrínsecas         q3
# 3   motivacao  Orientação a Metas Extrínsecas         q4
# 4   motivacao        Valorização da Atividade         q5
# 5   motivacao        Valorização da Atividade         q6
# 6   motivacao        Valorização da Atividade         q7
# 7   motivacao        Valorização da Atividade         q8
# 8   motivacao        Valorização da Atividade         q9
# 9   motivacao        Valorização da Atividade        q10
# 10  motivacao         Controle do Aprendizado        q11
# 11  motivacao         Controle do Aprendizado        q12
# 12  motivacao         Controle do Aprendizado        q13
# 13  motivacao   Autoeficácia para Aprendizado        q14
# 14  motivacao   Autoeficácia para Aprendizado        q15
# ...

# %%
orientação_a_metas_intrinsecas = 2.5
orientação_a_metas_Extrinsicas = 2.0
valorização_da_atividade = 3.6666666666666665
controle_do_aprendizado = 3.0
autoeficacia_para_aprendizado = 5.0
ansiedade_em_testes =3.2

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

constructors = ["orientação_a_metas_intrinsecas", "orientação_a_metas_Extrinsicas", "valorização_da_atividade", "controle_do_aprendizado",
"autoeficacia_para_aprendizado", "ansiedade_em_testes"]

counts = [2.5, 2.0, 3.66, 3.0, 5.0, 3.2]

ax.bar(constructors, counts)
plt.xticks(rotation=-45)
ax.set_ylabel('Escala')
ax.set_yticks([1,2,3,4,5,6,7])
ax.set_title('Perfil do estudante')

plt.show()
